# %% [markdown]
# # Case AON - Jefferson Lee Chan

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('case_aon.csv')

df.head()
# Out:
#    EMPRESA DATA_REFERENCIA  CODIGO_APOLICE TITULARIDADE     GENERO  IDADE  \
# 0     3209      2022-11-01        97000282   DEPENDENTE   FEMININO    2.0
# 1     3209      2022-11-01        97000282      TITULAR   FEMININO   58.0
# 2     3209      2022-11-01        97000284   DEPENDENTE  MASCULINO    9.0
# 3     3209      2022-11-01        97000284   DEPENDENTE  MASCULINO    9.0
# 4     3209      2022-11-01        97000284   DEPENDENTE  MASCULINO    9.0
#
#   DATA_ATENDIMENTO  FLAG_INTERNACAO CODIGO_INTERNACAO DATA_INTERNACAO  ...  \
# 0       2022-11-08            False               NaN             NaN  ...
# 1       2022-11-08            False               NaN             NaN  ...
# 2       2022-11-08            False               NaN             NaN  ...
# 3       2022-11-08            False               NaN             NaN  ...
# 4       2022-11-08            False               NaN             NaN  ...
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 877982 entries, 0 to 877981
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   EMPRESA                877982 non-null  int64
#  1   DATA_REFERENCIA        877982 non-null  object
#  2   CODIGO_APOLICE         877982 non-null  int64
#  3   TITULARIDADE           877982 non-null  object
#  4   GENERO                 877982 non-null  object
#  5   IDADE                  877545 non-null  float64
#  6   DATA_ATENDIMENTO       877981 non-null  object
#  7   FLAG_INTERNACAO        877982 non-null  bool
#  8   CODIGO_INTERNACAO      31303 non-null   object
#  9   DATA_INTERNACAO        57591 non-null   object
#  10  CODIGO_EVENTO          0 non-null       float64
#  11  VALOR_PAGO             877982 non-null  float64
#  12  DATA_PAGAMENTO_EVENTO  877982 non-null  object
#  13  QUANTIDADE_SERVICOS    877982 non-null  int64
# ...

# %%
df.describe().T
# Out:
#                         count          mean           std      min  \
# EMPRESA              877982.0  4.509225e+03  1.510194e+03   1733.0
# CODIGO_APOLICE       877982.0  9.260591e+07  1.707524e+07  25280.0
# IDADE                877545.0  3.592232e+01  1.699379e+01      0.0
# CODIGO_EVENTO             0.0           NaN           NaN      NaN
# VALOR_PAGO           877982.0  1.261962e+02  1.159935e+03 -25080.0
# QUANTIDADE_SERVICOS  877982.0  2.788285e+06  3.528485e+08      0.0
# EVENTO_OPERADORA      19993.0  1.271445e+03  6.535274e+02      0.0
# CODIGO_SERVICO       877982.0  3.806079e+07  2.645463e+07      0.0
#
#                              25%          50%          75%           max
# EMPRESA                  3209.00      3407.00      6310.00  6.365000e+03
# CODIGO_APOLICE       97000281.00  97010433.00  97016155.00  9.790062e+07
# IDADE                      25.00        36.00        48.00  9.900000e+01
# ...
